# %%
import pandas as pd

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('owid-covid-data.csv')

# %%
print (df.head(3))
# Out:
#   iso_code      continent location        date  total_cases  new_cases  \
# 0      ABW  North America    Aruba  2020-03-13          2.0        2.0
# 1      ABW  North America    Aruba  2020-03-19          NaN        NaN
# 2      ABW  North America    Aruba  2020-03-20          4.0        2.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           0.0         0.0                  NaN  ...
# 1               0.286           NaN         NaN                  0.0  ...
# 2               0.286           0.0         0.0                  0.0  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0       35973.781              NaN                    NaN
# 1       35973.781              NaN                    NaN
# 2       35973.781              NaN                    NaN
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
df.loc[df['continent'] == 'North America']
# Out:
#       iso_code      continent                      location        date  \
# 0          ABW  North America                         Aruba  2020-03-13
# 1          ABW  North America                         Aruba  2020-03-19
# 2          ABW  North America                         Aruba  2020-03-20
# 3          ABW  North America                         Aruba  2020-03-21
# 4          ABW  North America                         Aruba  2020-03-22
# ...        ...            ...                           ...         ...
# 47942      VIR  North America  United States Virgin Islands  2020-10-09
# 47943      VIR  North America  United States Virgin Islands  2020-10-10
# 47944      VIR  North America  United States Virgin Islands  2020-10-11
# 47945      VIR  North America  United States Virgin Islands  2020-10-12
# 47946      VIR  North America  United States Virgin Islands  2020-10-13
#
#        total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %%
df.loc[df['total_cases'] > 50]
# Out:
#       iso_code      continent       location        date  total_cases  \
# 14         ABW  North America          Aruba  2020-04-01         55.0
# 15         ABW  North America          Aruba  2020-04-02         55.0
# 16         ABW  North America          Aruba  2020-04-03         60.0
# 17         ABW  North America          Aruba  2020-04-04         62.0
# 18         ABW  North America          Aruba  2020-04-05         64.0
# ...        ...            ...            ...         ...          ...
# 49873      NaN            NaN  International  2020-10-09        696.0
# 49874      NaN            NaN  International  2020-10-10        696.0
# 49875      NaN            NaN  International  2020-10-11        696.0
# 49876      NaN            NaN  International  2020-10-12        696.0
# 49877      NaN            NaN  International  2020-10-13        696.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %%
df.loc[df['total_cases'] > 1000000]
# Out:
#        iso_code      continent location        date  total_cases  new_cases  \
# 6589        BRA  South America   Brazil  2020-06-20    1032913.0    54771.0
# 6590        BRA  South America   Brazil  2020-06-21    1067579.0    34666.0
# 6591        BRA  South America   Brazil  2020-06-22    1085038.0    17459.0
# 6592        BRA  South America   Brazil  2020-06-23    1106470.0    21432.0
# 6593        BRA  South America   Brazil  2020-06-24    1145906.0    39436.0
# ...         ...            ...      ...         ...          ...        ...
# 49585  OWID_WRL            NaN    World  2020-10-09   36611917.0   387973.0
# 49586  OWID_WRL            NaN    World  2020-10-10   36956458.0   344541.0
# 49587  OWID_WRL            NaN    World  2020-10-11   37296383.0   339925.0
# 49588  OWID_WRL            NaN    World  2020-10-12   37602785.0   306402.0
# 49589  OWID_WRL            NaN    World  2020-10-13   37875422.0   272637.0
#
# ...

# %%
df.groupby(['total_cases']).mean().sort_values('total_deaths', ascending=False)
# Out:
#                  new_cases  new_cases_smoothed  total_deaths   new_deaths  \
# total_cases
# 37875422.0   272637.000000       332831.571000  1.081632e+06  3912.000000
# 37602785.0   306402.000000       332232.000000  1.077720e+06  4037.000000
# 37296383.0   339925.000000       328909.571000  1.073683e+06  4720.000000
# 36956458.0   344541.000000       323840.714000  1.068963e+06  5720.000000
# 36611917.0   387973.000000       320160.286000  1.063243e+06  9118.000000
# ...                    ...                 ...           ...          ...
# 15.0              0.945455            0.486844  1.318182e-01     0.009091
# 3.0               0.327902            0.114603  9.572301e-02     0.006110
# 2.0               0.477987            0.157766  5.031447e-02     0.018868
# 1.0               0.219200            0.060901  9.600000e-03     0.004800
# 0.0               0.000000            0.000000  0.000000e+00     0.000000
#
#              new_deaths_smoothed  total_cases_per_million  \
# ...

# %%
df.tail(3)
# Out:
#       iso_code continent       location        date  total_cases  new_cases  \
# 49875      NaN       NaN  International  2020-10-11        696.0        NaN
# 49876      NaN       NaN  International  2020-10-12        696.0        NaN
# 49877      NaN       NaN  International  2020-10-13        696.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 49875                 NaN           7.0         NaN                  NaN  ...
# 49876                 NaN           7.0         NaN                  NaN  ...
# 49877                 NaN           7.0         NaN                  NaN  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 49875             NaN              NaN                    NaN
# 49876             NaN              NaN                    NaN
# 49877             NaN              NaN                    NaN
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# ...

# %%
df.head(3)
# Out:
#   iso_code      continent location        date  total_cases  new_cases  \
# 0      ABW  North America    Aruba  2020-03-13          2.0        2.0
# 1      ABW  North America    Aruba  2020-03-19          NaN        NaN
# 2      ABW  North America    Aruba  2020-03-20          4.0        2.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           0.0         0.0                  NaN  ...
# 1               0.286           NaN         NaN                  0.0  ...
# 2               0.286           0.0         0.0                  0.0  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0       35973.781              NaN                    NaN
# 1       35973.781              NaN                    NaN
# 2       35973.781              NaN                    NaN
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
print(df.tail(3))
# Out:
#       iso_code continent       location        date  total_cases  new_cases  \
# 49875      NaN       NaN  International  2020-10-11        696.0        NaN
# 49876      NaN       NaN  International  2020-10-12        696.0        NaN
# 49877      NaN       NaN  International  2020-10-13        696.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 49875                 NaN           7.0         NaN                  NaN  ...
# 49876                 NaN           7.0         NaN                  NaN  ...
# 49877                 NaN           7.0         NaN                  NaN  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 49875             NaN              NaN                    NaN
# 49876             NaN              NaN                    NaN
# 49877             NaN              NaN                    NaN
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49878 entries, 0 to 49877
# Data columns (total 41 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   iso_code                         49590 non-null  object
#  1   continent                        49302 non-null  object
#  2   location                         49878 non-null  object
#  3   date                             49878 non-null  object
#  4   total_cases                      49242 non-null  float64
#  5   new_cases                        49018 non-null  float64
#  6   new_cases_smoothed               48236 non-null  float64
#  7   total_deaths                     49242 non-null  float64
#  8   new_deaths                       49018 non-null  float64
#  9   new_deaths_smoothed              48236 non-null  float64
#  10  total_cases_per_million          48954 non-null  float64
# ...

# %%
df.total_cases.max()
# Out:
# 37875422.0

# %%
df.total_cases.min()
# Out:
# 0.0

# %%
df.total_cases.mean()
# Out:
# 117488.68547175176

# %%
df[df.location== "Brazil"]
# Out:
#      iso_code      continent location        date  total_cases  new_cases  \
# 6417      BRA  South America   Brazil  2019-12-31          0.0        0.0
# 6418      BRA  South America   Brazil  2020-01-01          0.0        0.0
# 6419      BRA  South America   Brazil  2020-01-02          0.0        0.0
# 6420      BRA  South America   Brazil  2020-01-03          0.0        0.0
# 6421      BRA  South America   Brazil  2020-01-04          0.0        0.0
# ...       ...            ...      ...         ...          ...        ...
# 6700      BRA  South America   Brazil  2020-10-09    5028444.0    27750.0
# 6701      BRA  South America   Brazil  2020-10-10    5055888.0    27444.0
# 6702      BRA  South America   Brazil  2020-10-11    5082637.0    26749.0
# 6703      BRA  South America   Brazil  2020-10-12    5094982.0    12345.0
# 6704      BRA  South America   Brazil  2020-10-13    5103408.0     8426.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df.groupby('total_cases').total_cases.max().sort_values()
# Out:
# total_cases
# 0.0                  0.0
# 1.0                  1.0
# 2.0                  2.0
# 3.0                  3.0
# 4.0                  4.0
#                  ...
# 36611917.0    36611917.0
# 36956458.0    36956458.0
# 37296383.0    37296383.0
# 37602785.0    37602785.0
# 37875422.0    37875422.0
# Name: total_cases, Length: 18777, dtype: float64

# %%
import matplotlib.pylab as plt

# %%
df.loc[df['life_expectancy'] > 77]
# Out:
#       iso_code      continent                      location        date  \
# 704        AIA  North America                      Anguilla  2020-03-27
# 705        AIA  North America                      Anguilla  2020-03-28
# 706        AIA  North America                      Anguilla  2020-03-29
# 707        AIA  North America                      Anguilla  2020-03-30
# 708        AIA  North America                      Anguilla  2020-03-31
# ...        ...            ...                           ...         ...
# 47942      VIR  North America  United States Virgin Islands  2020-10-09
# 47943      VIR  North America  United States Virgin Islands  2020-10-10
# 47944      VIR  North America  United States Virgin Islands  2020-10-11
# 47945      VIR  North America  United States Virgin Islands  2020-10-12
# 47946      VIR  North America  United States Virgin Islands  2020-10-13
#
#        total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...
