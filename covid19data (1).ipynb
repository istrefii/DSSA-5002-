# %%
import pandas as pd

# %%
import matplotlib.pylab as plt

# %%
import numpy as np

# %%
df = pd.read_csv('owid-covid-data.csv')

# %%
#look at the top linees of the data
print (df.head(3))
# Out:
#   iso_code      continent location        date  total_cases  new_cases  \
# 0      ABW  North America    Aruba  2020-03-13          2.0        2.0
# 1      ABW  North America    Aruba  2020-03-19          NaN        NaN
# 2      ABW  North America    Aruba  2020-03-20          4.0        2.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           0.0         0.0                  NaN  ...
# 1               0.286           NaN         NaN                  0.0  ...
# 2               0.286           0.0         0.0                  0.0  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0       35973.781              NaN                    NaN
# 1       35973.781              NaN                    NaN
# 2       35973.781              NaN                    NaN
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
# I want to know the total amount of cases and deaths in the world 
df.total_cases.sum()
# Out:
# 5785377850.0

# %%
df.total_deaths.sum()
# Out:
# 220561495.0

# %%
# I want to see the total cases in the USA
df_america = df[df.location == "United States"]

# %%
df_america[df_america.total_cases == df_america.total_cases.max()]
# Out:
#       iso_code      continent       location        date  total_cases  \
# 46690      USA  North America  United States  2020-10-13    7804197.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 46690    41653.0           49378.143      215085.0       314.0
#
#        new_deaths_smoothed  ...  gdp_per_capita  extreme_poverty  \
# 46690                699.0  ...       54225.446              1.2
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# 46690                151.089                10.79            19.1
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 46690          24.6                     NaN                        2.77
#
#        life_expectancy  human_development_index
# 46690            78.86                    0.924
#
# [1 rows x 41 columns]

# %%
#set a new variable that doesnt include world 
data_noworld= df[df.location != "World"]

# %%
#this shows which country had the most deaths and it happens to be the USA  
data_noworld[data_noworld.total_deaths == data_noworld.total_deaths.max()]
# Out:
#       iso_code      continent       location        date  total_cases  \
# 46690      USA  North America  United States  2020-10-13    7804197.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 46690    41653.0           49378.143      215085.0       314.0
#
#        new_deaths_smoothed  ...  gdp_per_capita  extreme_poverty  \
# 46690                699.0  ...       54225.446              1.2
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# 46690                151.089                10.79            19.1
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 46690          24.6                     NaN                        2.77
#
#        life_expectancy  human_development_index
# 46690            78.86                    0.924
#
# [1 rows x 41 columns]

# %%
#just me playing around with pandas seeing what funciton do what
data_noworld.groupby(['total_cases']).mean().sort_values('total_deaths', ascending=False)
# Out:
#                 new_cases  new_cases_smoothed   total_deaths   new_deaths  \
# total_cases
# 7804197.0    41653.000000        49378.143000  215085.000000   314.000000
# 7762544.0    43597.000000        49242.714000  214771.000000   394.000000
# 7718947.0    54271.000000        48000.429000  214377.000000   590.000000
# 7664676.0    58082.000000        47484.429000  213787.000000  1014.000000
# 7606594.0    56800.000000        46968.571000  212773.000000   972.000000
# ...                   ...                 ...            ...          ...
# 15.0             0.945455            0.486844       0.131818     0.009091
# 3.0              0.327902            0.114603       0.095723     0.006110
# 2.0              0.477987            0.157766       0.050314     0.018868
# 1.0              0.219200            0.060901       0.009600     0.004800
# 0.0              0.000000            0.000000       0.000000     0.000000
#
#              new_deaths_smoothed  total_cases_per_million  \
# ...

# %%
df.tail(3)
# Out:
#       iso_code continent       location        date  total_cases  new_cases  \
# 49875      NaN       NaN  International  2020-10-11        696.0        NaN
# 49876      NaN       NaN  International  2020-10-12        696.0        NaN
# 49877      NaN       NaN  International  2020-10-13        696.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 49875                 NaN           7.0         NaN                  NaN  ...
# 49876                 NaN           7.0         NaN                  NaN  ...
# 49877                 NaN           7.0         NaN                  NaN  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 49875             NaN              NaN                    NaN
# 49876             NaN              NaN                    NaN
# 49877             NaN              NaN                    NaN
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# ...

# %%
df.head(3)
# Out:
#   iso_code      continent location        date  total_cases  new_cases  \
# 0      ABW  North America    Aruba  2020-03-13          2.0        2.0
# 1      ABW  North America    Aruba  2020-03-19          NaN        NaN
# 2      ABW  North America    Aruba  2020-03-20          4.0        2.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           0.0         0.0                  NaN  ...
# 1               0.286           NaN         NaN                  0.0  ...
# 2               0.286           0.0         0.0                  0.0  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0       35973.781              NaN                    NaN
# 1       35973.781              NaN                    NaN
# 2       35973.781              NaN                    NaN
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
print(df.tail(3))
# Out:
#       iso_code continent       location        date  total_cases  new_cases  \
# 49875      NaN       NaN  International  2020-10-11        696.0        NaN
# 49876      NaN       NaN  International  2020-10-12        696.0        NaN
# 49877      NaN       NaN  International  2020-10-13        696.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 49875                 NaN           7.0         NaN                  NaN  ...
# 49876                 NaN           7.0         NaN                  NaN  ...
# 49877                 NaN           7.0         NaN                  NaN  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 49875             NaN              NaN                    NaN
# 49876             NaN              NaN                    NaN
# 49877             NaN              NaN                    NaN
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49878 entries, 0 to 49877
# Data columns (total 41 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   iso_code                         49590 non-null  object
#  1   continent                        49302 non-null  object
#  2   location                         49878 non-null  object
#  3   date                             49878 non-null  object
#  4   total_cases                      49242 non-null  float64
#  5   new_cases                        49018 non-null  float64
#  6   new_cases_smoothed               48236 non-null  float64
#  7   total_deaths                     49242 non-null  float64
#  8   new_deaths                       49018 non-null  float64
#  9   new_deaths_smoothed              48236 non-null  float64
#  10  total_cases_per_million          48954 non-null  float64
# ...

# %%
#find the max amount of cases
df.total_cases.max()
# Out:
# 37875422.0

# %%
data_noworld.location.unique()
# Out:
# array(['Aruba', 'Afghanistan', 'Angola', 'Anguilla', 'Albania', 'Andorra',
#        'United Arab Emirates', 'Argentina', 'Armenia',
#        'Antigua and Barbuda', 'Australia', 'Austria', 'Azerbaijan',
#        'Burundi', 'Belgium', 'Benin', 'Bonaire Sint Eustatius and Saba',
#        'Burkina Faso', 'Bangladesh', 'Bulgaria', 'Bahrain', 'Bahamas',
#        'Bosnia and Herzegovina', 'Belarus', 'Belize', 'Bermuda',
#        'Bolivia', 'Brazil', 'Barbados', 'Brunei', 'Bhutan', 'Botswana',
#        'Central African Republic', 'Canada', 'Switzerland', 'Chile',
#        'China', "Cote d'Ivoire", 'Cameroon',
#        'Democratic Republic of Congo', 'Congo', 'Colombia', 'Comoros',
#        'Cape Verde', 'Costa Rica', 'Cuba', 'Curacao', 'Cayman Islands',
#        'Cyprus', 'Czech Republic', 'Germany', 'Djibouti', 'Dominica',
#        'Denmark', 'Dominican Republic', 'Algeria', 'Ecuador', 'Egypt',
#        'Eritrea', 'Western Sahara', 'Spain', 'Estonia', 'Ethiopia',
# ...

# %%
# how to calculate fatality rate you divide the total death by total cases


df_noworld_deathrate= data_noworld.groupby('location').total_deaths.max() / data_noworld.groupby('location').total_cases.max() * 100

# %%
df_noworld_deathrate
# Out:
# location
# Afghanistan        3.706672
# Albania            2.723186
# Algeria            3.398779
# Andorra            1.903172
# Angola             3.424442
#                     ...
# Vietnam            3.153153
# Western Sahara     0.130548
# Yemen             28.988327
# Zambia             2.218792
# Zimbabwe           2.867473
# Length: 211, dtype: float64

# %%
#know I want to calucate the median age 
df_age65 = data_noworld.groupby('location').aged_65_older.mean()

# %%
df_age65
# Out:
# location
# Afghanistan        2.581
# Albania           13.188
# Algeria            6.211
# Andorra              NaN
# Angola             2.405
#                    ...
# Vietnam            7.150
# Western Sahara       NaN
# Yemen              2.922
# Zambia             2.480
# Zimbabwe           2.822
# Name: aged_65_older, Length: 211, dtype: float64

# %%
df_age65.corr(df_noworld_deathrate, method ='pearson') ** 2
# Out:
# 0.0023755476051216962

# %%
#the corrleation is very low and this makes me wonder. Isnt the age 65 or over more prone to face covid 19 problems.
